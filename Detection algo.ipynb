# %%
import cv2 
from matplotlib import pyplot as plt 
  
# Opening image 
img = cv2.imread("2Face_dect.jpg") 
  
# OpenCV opens images as BRG  
# but we want it as RGB We'll  
# also need a grayscale version 
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
  
# Use minSize because for not  
# bothering with extra-small  
# dots that would look like face
face_data = cv2.CascadeClassifier('face_cascade.xml')
#('face_cascade.xml')
found1 = face_data.detectMultiScale(img_gray,1.3,5)   
# Don't do anything if there's  
# no face 
amount_found = len(found1) 
  
if amount_found != 0: 
    # There may be more than one 
    # sign in the image 
    for (x, y, width, height) in found1: 
          
        # We draw a green rectangle around 
        # every recognized sign 
        cv2.rectangle(img_rgb, (x, y),(x + height, y + width), (0, 255, 0), 5) 

# Creates the environment of  
# the picture and shows it 
plt.subplot(1, 1, 1) 
plt.imshow(img_rgb) 
plt.show()

# %%
import cv2 
from matplotlib import pyplot as plt 
  
# Opening image 
img = cv2.imread("3Face_dect.jpg") 
  
# OpenCV opens images as BRG  
# but we want it as RGB We'll  
# also need a grayscale version 
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
  
# Use minSize because for not  
# bothering with extra-small  
# dots that would look like STOP signs 
eye_data = cv2.CascadeClassifier('haarcascade_eye.xml')
#('face_cascade.xml')
found1 = eye_data.detectMultiScale(img_gray,1.3,5)    
# Don't do anything if there's  
# no sign 
amount_found = len(found1) 
  
if amount_found != 0: 
    # There may be more than one 
    # sign in the image 
    for (x, y, width, height) in found1: 
          
        # We draw a green rectangle around 
        # every recognized sign 
        cv2.rectangle(img_rgb, (x, y),(x + height, y + width), (0, 255, 0), 5) 
# Creates the environment of  
# the picture and shows it 
plt.subplot(1, 1, 1) 
plt.imshow(img_rgb) 
plt.show()
